# %% [markdown]
# # Introduction (default heading)

# %% [markdown]
# ### What is Sens Analysis? (Short intro into what topic means)
#
# 'Research & analysis of how changes in LPs parameters affect the optimal solution'

# %% [markdown]
# ### Most important case to demonstrate: Financial and resource allocation problems

# %% [markdown]
# Shadow prices allow for efficient exploration of other ajanced LP's without resolving the whole system. (Time demo here?)
#
# This has three important implications:
# - Calculation of possible improvements to the cost, assuming current basis remains optimal
# - Exploration of bounds of the current optimal basis by changing with what we have
# - Exploration of bounds of the current optimal basis by bringing in something new
